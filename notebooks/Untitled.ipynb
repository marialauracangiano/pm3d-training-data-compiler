# %%
from analytics_pipeline.processing.datasets.calibration import build_calibration_dataset
import pandas as pd
from pathlib import Path

biomass_df = pd.read_csv("data/processed/biomass_master.csv")
image_df = pd.read_csv("data/processed/image_master.csv")

build_calibration_dataset(
    biomass_df,
    image_df,
    diagnostics=True,
    output_dir=Path("data/processed"),
)
# Out:
#      Image Name (from PlantMap3D app) Sample Date  timing plot_id Species  \
# 0         AL-Wolfe_2024_TM-1_PL-AU1-1     5/30/24     1.0   AU1-1     Oat
# 1         AL-Wolfe_2024_TM-1_PL-AU1-1     5/30/24     1.0   AU1-1     Oat
# 2         AL-Wolfe_2024_TM-1_PL-AU1-1     5/30/24     1.0   AU1-1     Oat
# 3         AL-Wolfe_2024_TM-1_PL-AU1-1     5/30/24     1.0   AU1-1     Oat
# 4         AL-Wolfe_2024_TM-1_PL-AU1-1     5/30/24     1.0   AU1-1   Other
# ...                               ...         ...     ...     ...     ...
# 7852      NY-Jannink_2025_TM-3_PL-1.3   7/14/2025     3.0     1.3     Pea
# 7853      NY-Jannink_2025_TM-3_PL-1.3   7/14/2025     3.0     1.3   Other
# 7854      NY-Jannink_2025_TM-3_PL-1.3   7/14/2025     3.0     1.3   Other
# 7855      NY-Jannink_2025_TM-3_PL-1.3   7/14/2025     3.0     1.3   Other
# 7856      NY-Jannink_2025_TM-3_PL-1.3   7/14/2025     3.0     1.3   Other
#
#       dry_weight_g                Trial_Plot ID  \
# ...

# %%
import analytics_pipeline.processing.datasets as d
print(dir(d))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'biomass_master', 'build_biomass_master', 'calibration']
